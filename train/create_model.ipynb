# %%
from pyspark.ml.feature import HashingTF, IDF, Tokenizer
from pyspark.ml.regression import RandomForestRegressor
from pyspark.ml import Pipeline

from pyspark.sql import SparkSession
from pyspark.sql.functions import col

# %%
spark = SparkSession.builder \
    .appName("SalaryPrediction") \
    .getOrCreate()

data = spark.read.csv("./jobs.csv", header=True, inferSchema=True, sep=";", multiLine=True)


data.show()
data.printSchema()

data.select("description").show()
data.select("sal_high").show()

data = data.withColumn("mean_salary", (col("sal_high") + col("sal_low")) / 2)

df = data.select(col('description'),
               col('mean_salary').alias('salary'))

df = df.dropna()
df.select('salary').show()
df.select('description').show(truncate=False)
# Out:
# +---------------+--------------------+--------------------+----------------+-----------------+-----------+----+--------------------+---------------+----------------+-----------------+----------+--------------------+--------+--------+--------------------+--------------------+
# |Employment type|          Industries|        Job function| Seniority level|          company| company_id|date|         description|      education|        location|months_experience|   post_id|            post_url|sal_high| sal_low|              salary|               title|
# +---------------+--------------------+--------------------+----------------+-----------------+-----------+----+--------------------+---------------+----------------+-----------------+----------+--------------------+--------+--------+--------------------+--------------------+
# |      Full-time|     Broadcast Media|Information Techn...|Mid-Senior level|      CyberCoders|    21836.0|NULL|Job Title: Senior...|bachelor degree|  Alexandria, VA|             60.0|2632814552|https://www.linke...|    NULL|    NULL|                NULL|Senior Data Engineer|
# |      Full-time|Hospital & Health...|Engineering and I...|  Not Applicable|Johnson & Johnson|     1207.0|NULL|Ethicon, part of ...|bachelor degree| Santa Clara, CA|             96.0|2632810866|https://www.linke...|    NULL|    NULL|                NULL|Principal Full St...|
# |      Full-time|Computer Hardware...|Engineering and I...|  Not Applicable|        Microsoft|     1035.0|NULL|Microsoft’s WCB h...|bachelor degree|  Washington, DC|             84.0|2632812746|https://www.linke...|189000.0|120000.0|$120,000.00/yr - ...|Senior Software E...|
# |      Full-time|Computer Hardware...|Engineering and I...|  Not Applicable|        Microsoft|     1035.0|NULL|Microsoft’s WCB h...|bachelor degree|      Reston, VA|             84.0|2632817427|https://www.linke...|189000.0|120000.0|$120,000.00/yr - ...|Senior Software E...|
# |      Full-time|Computer Hardware...|Engineering and I...|  Not Applicable|        Microsoft|     1035.0|NULL|Microsoft’s WCB h...|bachelor degree|      Irving, TX|             84.0|2632817426|https://www.linke...|175000.0|108000.0|$108,000.00/yr - ...|Senior Software E...|
# |      Full-time|Computer Hardware...|Engineering and I...|  Not Applicable|        Microsoft|     1035.0|NULL|Microsoft’s WCB h...|bachelor degree|     Atlanta, GA|             84.0|2632813731|https://www.linke...|172000.0|106000.0|$106,000.00/yr - ...|Senior Software E...|
# |      Full-time|Computer Hardware...|Engineering and I...|  Not Applicable|        Microsoft|     1035.0|NULL|Microsoft’s WCB h...|bachelor degree|   Charlotte, NC|             84.0|2632813729|https://www.linke...|170000.0|105000.0|$105,000.00/yr - ...|Senior Software E...|
# |      Full-time|                NULL|                NULL|            NULL|          Cleerly|3.4949677E7|NULL|Position Title: S...|bachelor degree|      Denver, CO|             24.0|2632813714|https://www.linke...|200000.0|130000.0|$130,000.00/yr - ...|Staff - Data Scie...|
# |      Full-time|Computer Hardware...|Engineering and I...|  Not Applicable|        Microsoft|     1035.0|NULL|Are you passionat...|bachelor degree|      Reston, VA|             60.0|2632811819|https://www.linke...|189000.0|120000.0|$120,000.00/yr - ...|Senior Software E...|
# |      Full-time|Computer Hardware...|Engineering and I...|  Not Applicable|        Microsoft|     1035.0|NULL|Are you passionat...|bachelor degree|   Charlotte, NC|             60.0|2632814538|https://www.linke...|170000.0|105000.0|$105,000.00/yr - ...|Senior Software E...|
# |      Full-time|Computer Hardware...|Engineering and I...|  Not Applicable|        Microsoft|     1035.0|NULL|Are you passionat...|bachelor degree|     Atlanta, GA|             60.0|2632811815|https://www.linke...|172000.0|106000.0|$106,000.00/yr - ...|Senior Software E...|
# |      Full-time|Computer Hardware...|Engineering and I...|  Not Applicable|        Microsoft|     1035.0|NULL|Are you passionat...|bachelor degree|  Washington, DC|             60.0|2632810853|https://www.linke...|189000.0|120000.0|$120,000.00/yr - ...|Senior Software E...|
# |      Full-time|Computer Hardware...|Engineering and I...|  Not Applicable|        Microsoft|     1035.0|NULL|Are you passionat...|bachelor degree|      Irving, TX|             60.0|2632813725|https://www.linke...|175000.0|108000.0|$108,000.00/yr - ...|Senior Software E...|
# |      Full-time|Computer Hardware...|Engineering and I...|  Not Applicable|        Microsoft|     1035.0|NULL|Core Services Eng...|bachelor degree|     Redmond, WA|             96.0|2632815588|https://www.linke...|147000.0|109000.0|$109,000.00/yr - ...|   Software Engineer|
# |      Full-time|Hospital & Health...|Engineering and I...|  Not Applicable|Johnson & Johnson|     1207.0|NULL|Ethicon, part of ...|bachelor degree|     Seattle, WA|             96.0|2632812728|https://www.linke...|    NULL|    NULL|                NULL|Principal Full St...|
# |      Full-time|Computer Software...|Information Techn...|     Entry level|  The Shade Store|  1243847.0|NULL|"THE POSITION: QA...|bachelor degree|Port Chester, NY|             60.0|2632814529|https://www.linke...|    NULL|    NULL|                NULL|QA Software Testi...|
# |      Full-time|Computer Hardware...|Engineering and I...|  Not Applicable|        Microsoft|     1035.0|NULL|Microsoft’s WCB h...|bachelor degree|     Chicago, IL|             84.0|2632810847|https://www.linke...|179000.0|111000.0|$111,000.00/yr - ...|Senior Software E...|
# |      Full-time|Hospital & Health...|Engineering and I...|  Not Applicable|Johnson & Johnson|     1207.0|NULL|Ethicon, part of ...|bachelor degree|     Seattle, WA|             36.0|2632812727|https://www.linke...|    NULL|    NULL|                NULL|Senior Full Stack...|
# |      Full-time|Computer Hardware...|Engineering and I...|  Not Applicable|        Microsoft|     1035.0|NULL|Microsoft’s WCB h...|bachelor degree|   San Diego, CA|             84.0|2632813720|https://www.linke...|186000.0|115000.0|$115,000.00/yr - ...|Senior Software E...|
# |      Full-time|Computer Hardware...|Engineering and I...|  Not Applicable|        Microsoft|     1035.0|NULL|Microsoft’s WCB h...|bachelor degree|   Charlotte, NC|             84.0|2632816592|https://www.linke...|170000.0|105000.0|$105,000.00/yr - ...|Senior Software E...|
# +---------------+--------------------+--------------------+----------------+-----------------+-----------+----+--------------------+---------------+----------------+-----------------+----------+--------------------+--------+--------+--------------------+--------------------+
# only showing top 20 rows
#
# root
#  |-- Employment type: string (nullable = true)
#  |-- Industries: string (nullable = true)
#  |-- Job function: string (nullable = true)
#  |-- Seniority level: string (nullable = true)
#  |-- company: string (nullable = true)
#  |-- company_id: double (nullable = true)
#  |-- date: timestamp (nullable = true)
#  |-- description: string (nullable = true)
#  |-- education: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- months_experience: string (nullable = true)
#  |-- post_id: string (nullable = true)
#  |-- post_url: string (nullable = true)
#  |-- sal_high: string (nullable = true)
#  |-- sal_low: string (nullable = true)
#  |-- salary: string (nullable = true)
#  |-- title: string (nullable = true)
#
# +--------------------+
# |         description|
# +--------------------+
# |Job Title: Senior...|
# |Ethicon, part of ...|
# |Microsoft’s WCB h...|
# |Microsoft’s WCB h...|
# |Microsoft’s WCB h...|
# |Microsoft’s WCB h...|
# |Microsoft’s WCB h...|
# |Position Title: S...|
# |Are you passionat...|
# |Are you passionat...|
# |Are you passionat...|
# |Are you passionat...|
# |Are you passionat...|
# |Core Services Eng...|
# |Ethicon, part of ...|
# |"THE POSITION: QA...|
# |Microsoft’s WCB h...|
# |Ethicon, part of ...|
# |Microsoft’s WCB h...|
# |Microsoft’s WCB h...|
# +--------------------+
# only showing top 20 rows
#
# +--------+
# |sal_high|
# +--------+
# |    NULL|
# |    NULL|
# |189000.0|
# |189000.0|
# |175000.0|
# |172000.0|
# |170000.0|
# |200000.0|
# |189000.0|
# |170000.0|
# |172000.0|
# |189000.0|
# |175000.0|
# |147000.0|
# |    NULL|
# |    NULL|
# |179000.0|
# |    NULL|
# |186000.0|
# |170000.0|
# +--------+
# only showing top 20 rows
#
# +--------+
# |  salary|
# +--------+
# |154500.0|
# |154500.0|
# |141500.0|
# |139000.0|
# |137500.0|
# |165000.0|
# |154500.0|
# |137500.0|
# |139000.0|
# |154500.0|
# |141500.0|
# |128000.0|
# |145000.0|
# |150500.0|
# |137500.0|
# |154500.0|
# |154500.0|
# |135000.0|
# |133900.0|
# |139000.0|
# +--------+
# only showing top 20 rows
#
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |Microsoft’s WCB health team is looking for a Senior Software Engineer who loves to learn, solve challenges, and be a part of a team working to collaborate with healthcare partners to help people navigate complicated systems such as healthcare. You may have worked on similar projects, or you're looking for a new adventure. To be successful in this role, you value open communication and breaking down technical complexity. You are energized by sharing the knowledge you hold to improve the team you are on. You are capable of visualizing and driving toward long-term success while addressing and solving for immediate uncertainties. You are comfortable dealing with the ambiguities that come from being the driving force for change in an industry. You embrace diversity of experience and thought. You’re a tireless advocate for the customer and great engineering practices—enthusiastic about building and iterating on designs to discover what works best and applying your knowledge to create incredibly reliable, scalable and delightful consumer experiences. You're passionate about your interests, and you want to work on projects that will challenge your technical and collaborative capabilities. You understand how to be on a collaborative team as a leader with the ability to solve difficult engineering problems, point out what's not quite right, mentor others towards better answers and smooth the customer’s journey through physical and digital footprints. You find ways to reduce the number of steps to secure and scalable systems by using every tool in the toolbox. You’ll work in a focused team collaborating with large internal and external partners in healthcare. Bouncing ideas around, formulating plans, and charting the path forward for the future of healthcare. Responsibilities Understand customer's overall technical requirements, priorities and success measures to design system architecture and implementation paths. Maintain and advance deep technical skills and knowledge, keeping up to date with market trends and competitive insights. Work with program managers to understand customer needs and provide insights and best practices. Design, code, debug, and problem-solve with internal and external members of the team on a wide array of proposed web, desktop and mobile experiences. Create a track record of driving decisions collaboratively, resolving conflicts and blockers with creative problem-solving and ensuring follow through with exceptional verbal and written communication skills. Required Qualifications Bachelor's in engineering related field or 7+ years of relative experience. 5 years of coding skills in at least one general purpose programming language (Java, C#, JavaScript, etc). Familiar with at least one major cloud provider (Azure, AWS, GCP, or other). Breadth of technical experience and knowledge as well as depth in at least one of the following areas: Database architecture, ETL, Data Mining, Business Intelligence, Big Data, Advance Analytics, Data Structure, Data Mining, Data Governance, FHIR, HL7, Desktop or Web Frontend UX. Preferred Experience with either retail or healthcare companies. Dynamics 365 experience Prior work experience in a Consulting/Delivery/Architecture position within a software and/or services company. Proven track record of building deep technical relationships with senior IT architects to engineers. Demonstrated ability to adapt to new technologies and learn quickly to enable migrating or transforming legacy customer solution to cloud-based platform as a service. Ability to communicate concisely and effectively with other executives, employees, partners, and communities. Microsoft is an equal opportunity employer. All qualified applicants will receive consideration for employment without regard to age, ancestry, color, family or medical care leave, gender identity or expression, genetic information, marital status, medical condition, national origin, physical or mental disability, political affiliation, ...
# |Microsoft’s WCB health team is looking for a Senior Software Engineer who loves to learn, solve challenges, and be a part of a team working to collaborate with healthcare partners to help people navigate complicated systems such as healthcare. You may have worked on similar projects, or you're looking for a new adventure. To be successful in this role, you value open communication and breaking down technical complexity. You are energized by sharing the knowledge you hold to improve the team you are on. You are capable of visualizing and driving toward long-term success while addressing and solving for immediate uncertainties. You are comfortable dealing with the ambiguities that come from being the driving force for change in an industry. You embrace diversity of experience and thought. You’re a tireless advocate for the customer and great engineering practices—enthusiastic about building and iterating on designs to discover what works best and applying your knowledge to create incredibly reliable, scalable and delightful consumer experiences. You're passionate about your interests, and you want to work on projects that will challenge your technical and collaborative capabilities. You understand how to be on a collaborative team as a leader with the ability to solve difficult engineering problems, point out what's not quite right, mentor others towards better answers and smooth the customer’s journey through physical and digital footprints. You find ways to reduce the number of steps to secure and scalable systems by using every tool in the toolbox. You’ll work in a focused team collaborating with large internal and external partners in healthcare. Bouncing ideas around, formulating plans, and charting the path forward for the future of healthcare. Responsibilities Understand customer's overall technical requirements, priorities and success measures to design system architecture and implementation paths. Maintain and advance deep technical skills and knowledge, keeping up to date with market trends and competitive insights. Work with program managers to understand customer needs and provide insights and best practices. Design, code, debug, and problem-solve with internal and external members of the team on a wide array of proposed web, desktop and mobile experiences. Create a track record of driving decisions collaboratively, resolving conflicts and blockers with creative problem-solving and ensuring follow through with exceptional verbal and written communication skills. Required Qualifications Bachelor's in engineering related field or 7+ years of relative experience. 5 years of coding skills in at least one general purpose programming language (Java, C#, JavaScript, etc). Familiar with at least one major cloud provider (Azure, AWS, GCP, or other). Breadth of technical experience and knowledge as well as depth in at least one of the following areas: Database architecture, ETL, Data Mining, Business Intelligence, Big Data, Advance Analytics, Data Structure, Data Mining, Data Governance, FHIR, HL7, Desktop or Web Frontend UX. Preferred Experience with either retail or healthcare companies. Dynamics 365 experience Prior work experience in a Consulting/Delivery/Architecture position within a software and/or services company. Proven track record of building deep technical relationships with senior IT architects to engineers. Demonstrated ability to adapt to new technologies and learn quickly to enable migrating or transforming legacy customer solution to cloud-based platform as a service. Ability to communicate concisely and effectively with other executives, employees, partners, and communities. Microsoft is an equal opportunity employer. All qualified applicants will receive consideration for employment without regard to age, ancestry, color, family or medical care leave, gender identity or expression, genetic information, marital status, medical condition, national origin, physical or mental disability, political affiliation, ...
# |Microsoft’s WCB health team is looking for a Senior Software Engineer who loves to learn, solve challenges, and be a part of a team working to collaborate with healthcare partners to help people navigate complicated systems such as healthcare. You may have worked on similar projects, or you're looking for a new adventure. To be successful in this role, you value open communication and breaking down technical complexity. You are energized by sharing the knowledge you hold to improve the team you are on. You are capable of visualizing and driving toward long-term success while addressing and solving for immediate uncertainties. You are comfortable dealing with the ambiguities that come from being the driving force for change in an industry. You embrace diversity of experience and thought. You’re a tireless advocate for the customer and great engineering practices—enthusiastic about building and iterating on designs to discover what works best and applying your knowledge to create incredibly reliable, scalable and delightful consumer experiences. You're passionate about your interests, and you want to work on projects that will challenge your technical and collaborative capabilities. You understand how to be on a collaborative team as a leader with the ability to solve difficult engineering problems, point out what's not quite right, mentor others towards better answers and smooth the customer’s journey through physical and digital footprints. You find ways to reduce the number of steps to secure and scalable systems by using every tool in the toolbox. You’ll work in a focused team collaborating with large internal and external partners in healthcare. Bouncing ideas around, formulating plans, and charting the path forward for the future of healthcare. Responsibilities Understand customer's overall technical requirements, priorities and success measures to design system architecture and implementation paths. Maintain and advance deep technical skills and knowledge, keeping up to date with market trends and competitive insights. Work with program managers to understand customer needs and provide insights and best practices. Design, code, debug, and problem-solve with internal and external members of the team on a wide array of proposed web, desktop and mobile experiences. Create a track record of driving decisions collaboratively, resolving conflicts and blockers with creative problem-solving and ensuring follow through with exceptional verbal and written communication skills. Required Qualifications Bachelor's in engineering related field or 7+ years of relative experience. 5 years of coding skills in at least one general purpose programming language (Java, C#, JavaScript, etc). Familiar with at least one major cloud provider (Azure, AWS, GCP, or other). Breadth of technical experience and knowledge as well as depth in at least one of the following areas: Database architecture, ETL, Data Mining, Business Intelligence, Big Data, Advance Analytics, Data Structure, Data Mining, Data Governance, FHIR, HL7, Desktop or Web Frontend UX. Preferred Experience with either retail or healthcare companies. Dynamics 365 experience Prior work experience in a Consulting/Delivery/Architecture position within a software and/or services company. Proven track record of building deep technical relationships with senior IT architects to engineers. Demonstrated ability to adapt to new technologies and learn quickly to enable migrating or transforming legacy customer solution to cloud-based platform as a service. Ability to communicate concisely and effectively with other executives, employees, partners, and communities. Microsoft is an equal opportunity employer. All qualified applicants will receive consideration for employment without regard to age, ancestry, color, family or medical care leave, gender identity or expression, genetic information, marital status, medical condition, national origin, physical or mental disability, political affiliation, ...
# |Microsoft’s WCB health team is looking for a Senior Software Engineer who loves to learn, solve challenges, and be a part of a team working to collaborate with healthcare partners to help people navigate complicated systems such as healthcare. You may have worked on similar projects, or you're looking for a new adventure. To be successful in this role, you value open communication and breaking down technical complexity. You are energized by sharing the knowledge you hold to improve the team you are on. You are capable of visualizing and driving toward long-term success while addressing and solving for immediate uncertainties. You are comfortable dealing with the ambiguities that come from being the driving force for change in an industry. You embrace diversity of experience and thought. You’re a tireless advocate for the customer and great engineering practices—enthusiastic about building and iterating on designs to discover what works best and applying your knowledge to create incredibly reliable, scalable and delightful consumer experiences. You're passionate about your interests, and you want to work on projects that will challenge your technical and collaborative capabilities. You understand how to be on a collaborative team as a leader with the ability to solve difficult engineering problems, point out what's not quite right, mentor others towards better answers and smooth the customer’s journey through physical and digital footprints. You find ways to reduce the number of steps to secure and scalable systems by using every tool in the toolbox. You’ll work in a focused team collaborating with large internal and external partners in healthcare. Bouncing ideas around, formulating plans, and charting the path forward for the future of healthcare. Responsibilities Understand customer's overall technical requirements, priorities and success measures to design system architecture and implementation paths. Maintain and advance deep technical skills and knowledge, keeping up to date with market trends and competitive insights. Work with program managers to understand customer needs and provide insights and best practices. Design, code, debug, and problem-solve with internal and external members of the team on a wide array of proposed web, desktop and mobile experiences. Create a track record of driving decisions collaboratively, resolving conflicts and blockers with creative problem-solving and ensuring follow through with exceptional verbal and written communication skills. Required Qualifications Bachelor's in engineering related field or 7+ years of relative experience. 5 years of coding skills in at least one general purpose programming language (Java, C#, JavaScript, etc). Familiar with at least one major cloud provider (Azure, AWS, GCP, or other). Breadth of technical experience and knowledge as well as depth in at least one of the following areas: Database architecture, ETL, Data Mining, Business Intelligence, Big Data, Advance Analytics, Data Structure, Data Mining, Data Governance, FHIR, HL7, Desktop or Web Frontend UX. Preferred Experience with either retail or healthcare companies. Dynamics 365 experience Prior work experience in a Consulting/Delivery/Architecture position within a software and/or services company. Proven track record of building deep technical relationships with senior IT architects to engineers. Demonstrated ability to adapt to new technologies and learn quickly to enable migrating or transforming legacy customer solution to cloud-based platform as a service. Ability to communicate concisely and effectively with other executives, employees, partners, and communities. Microsoft is an equal opportunity employer. All qualified applicants will receive consideration for employment without regard to age, ancestry, color, family or medical care leave, gender identity or expression, genetic information, marital status, medical condition, national origin, physical or mental disability, political affiliation, ...
# |Microsoft’s WCB health team is looking for a Senior Software Engineer who loves to learn, solve challenges, and be a part of a team working to collaborate with healthcare partners to help people navigate complicated systems such as healthcare. You may have worked on similar projects, or you're looking for a new adventure. To be successful in this role, you value open communication and breaking down technical complexity. You are energized by sharing the knowledge you hold to improve the team you are on. You are capable of visualizing and driving toward long-term success while addressing and solving for immediate uncertainties. You are comfortable dealing with the ambiguities that come from being the driving force for change in an industry. You embrace diversity of experience and thought. You’re a tireless advocate for the customer and great engineering practices—enthusiastic about building and iterating on designs to discover what works best and applying your knowledge to create incredibly reliable, scalable and delightful consumer experiences. You're passionate about your interests, and you want to work on projects that will challenge your technical and collaborative capabilities. You understand how to be on a collaborative team as a leader with the ability to solve difficult engineering problems, point out what's not quite right, mentor others towards better answers and smooth the customer’s journey through physical and digital footprints. You find ways to reduce the number of steps to secure and scalable systems by using every tool in the toolbox. You’ll work in a focused team collaborating with large internal and external partners in healthcare. Bouncing ideas around, formulating plans, and charting the path forward for the future of healthcare. Responsibilities Understand customer's overall technical requirements, priorities and success measures to design system architecture and implementation paths. Maintain and advance deep technical skills and knowledge, keeping up to date with market trends and competitive insights. Work with program managers to understand customer needs and provide insights and best practices. Design, code, debug, and problem-solve with internal and external members of the team on a wide array of proposed web, desktop and mobile experiences. Create a track record of driving decisions collaboratively, resolving conflicts and blockers with creative problem-solving and ensuring follow through with exceptional verbal and written communication skills. Required Qualifications Bachelor's in engineering related field or 7+ years of relative experience. 5 years of coding skills in at least one general purpose programming language (Java, C#, JavaScript, etc). Familiar with at least one major cloud provider (Azure, AWS, GCP, or other). Breadth of technical experience and knowledge as well as depth in at least one of the following areas: Database architecture, ETL, Data Mining, Business Intelligence, Big Data, Advance Analytics, Data Structure, Data Mining, Data Governance, FHIR, HL7, Desktop or Web Frontend UX. Preferred Experience with either retail or healthcare companies. Dynamics 365 experience Prior work experience in a Consulting/Delivery/Architecture position within a software and/or services company. Proven track record of building deep technical relationships with senior IT architects to engineers. Demonstrated ability to adapt to new technologies and learn quickly to enable migrating or transforming legacy customer solution to cloud-based platform as a service. Ability to communicate concisely and effectively with other executives, employees, partners, and communities. Microsoft is an equal opportunity employer. All qualified applicants will receive consideration for employment without regard to age, ancestry, color, family or medical care leave, gender identity or expression, genetic information, marital status, medical condition, national origin, physical or mental disability, political affiliation, ...
# |Position Title: Staff Data Scientist Position: Full Time, Exempt Supervises Staff: No Salary Range: $130,000 - $200,000 Please note this position is in Denver, CO. Cleerly will not sponsor a visa for this position. Job Description We’re Cleerly, a healthcare company based in Denver, Colorado and New York, New York that’s revolutionizing how heart disease is diagnosed, treated and tracked. We were founded 3 years ago by one of the leading cardiologists in the world and are a world-class team of engineers, designers, product managers, and data scientists backed by leading healthcare VCs. We have an immediate opening for a Staff-level Data Science leader to drive our machine learning strategy and development process. We’re searching for someone excited to work on novel technologies and develop the next generation of quantitative computer aided diagnosis systems. Are you an experienced data scientist with an excellent academic background?  Do you have a passion for image analysis and deep learning?  Have you shipped production models in a commercial setting? If the answer to these is yes, then we’d like to talk with you. What would I be doing? You’ll be working in a multi-disciplinary, cross-functional team to research, analyze, and build our ML algorithms and pipeline. You’ll work with other engineers to build a culture and approach focused on MLOps strategies. On any given day you could be: Researching new methods of measuring and analyzing large and highly complicated data sets Working with distinguished clinical researchers worldwide to validate new technologies Developing a new algorithm for image analysis Training and validating your image-based models for medical applications Building prototypes for experimentation Presenting findings and recommendations to groups of clinical experts and other stakeholders Designing the software interface for a model to deliver it into production Creating annotation solutions for 2D and 3D image labeling Staying abreast of current and novel developments in the field through reading, conferences, and other research opportunities Qualifications Ph.D. in an area of computational sciences and deep knowledge of the physics of image formation 2 or more years of commercial experience in deep learning Strong theoretical and practical background in image science, applied mathematics, machine learning, deep learning Significant experience with large-scale machine learning platforms such as PyTorch or TensorFlow Strong skills with your programming language of choice such as Python, Julia or R to access large amounts of data, execute multiple analysis steps, visualize intermediate and final results Demonstrated ability of prototype development Expertise in advanced data analytics, including structured & unstructured data, data mining, and ML techniques Ability to communicate complex concepts to both scientists and non-scientists A team-oriented individual that works collaboratively to achieve team goals Ability to exercise discretion and tact, and protect confidentiality where required Impress us more… Expertise in medical intelligence, medical imaging and data processing Experience in health care, education, or research fields Experience with development of DICOM- and end-user image-based software Published machine learning papers in top CS and medical journals Cleerly offers competitive benefits, including medical, dental, and life insurance; generous PTO, stock options, and 401K. OUR COMPANY IS AN EQUAL OPPORTUNITY EMPLOYER. We do not discriminate on the basis of race, color, national origin, ancestry, citizenship status, protected veteran status, religion, physical or mental disability, marital status, sex, sexual orientation, gender identity or expression, age, or any other basis protected by law, ordinance, or regulation. Job duties, activities and responsibilities are subject to change by our company.                                                                                                ...
# ...
# |Senior Scientist Neurodegeneration Discovery AI/ML and Informatics Research Job Description Janssen Research & Development is recruiting for Senior Scientist, Neurodegeneration Discovery AI/ML, located in Titusville, NJ or Beerse, Belgium! This outstanding data scientist will craft impactful data science solutions to the challenge of identifying and validating of novel targets to progress through preclinical and experimental medicine studies. We analyze high-dimensional molecular datasets from preclinical models generated and human data from both research and real-world sources, developing methodologies to link data to mechanistic hypotheses. You will be part of our high-performing, cross-functional team of bioinformaticians, data scientists and discovery scientists at Janssen, and as part of our collaborations with top external partners in academia and industry. The role requires knowledge of sophisticated analytics including linking bioinformatics with artificial intelligence and machine learning, inventing and customizing novel methods. Key Responsibilities The candidate will lead machine learning initiatives integrating across a wide range of molecular data types to support Target Identification and Validation for Alzheimer's, Parkinson's and other neurodegenerative diseases. The candidate's work will be tightly coupled with our computational chemistry and high content imaging programs in the discovery organization, and with our Neurodegeneration Disease Area in the Neuroscience Therapeuticc Area. Support large scale data analytics driving target identification, validation, and evaluating target profiles in human disease, for neurodegeneration and neuroimmunology. You will assist in reviewing, updating and refreshing data science plans in preparation of first-in-human and early development studies. You will support critical initiatives and help drive analytics strategies around new data types, such as single cell sequencing. You will remain current on the constantly evolving landscape of neuroscience, neurodegeneration, genomics, bioinformatics and AIML research in search of better strategies for prioritizing our portfolio based on biological insights. Qualifications Qualifications Education PhD with 2-5 years of progressive experience in a computational or physical science with prior applying data science to life sciences. A degree in a biological science with extensive application of data science methodologies will also be considered. Required Experience and Skills: Extensive background working hands-on deriving insights from high-dimensional molecular data, particularly genetic, RNAseq, and/or single cell data. Internationally recognized track record of scientific contributions in this field with first author publications in high-impact journals. Ability to translate data into information and strategies into executable action plans. Known for driving towards novel solutions to problems (often sought after for strategic advice) Experience in leading interdisciplinary teams including scientists and clinicians. Ability to clearly communicate technical work to a diverse audience is required. Preferred Background and experience working in Neuroscience Familiarity with drug discovery and clinical development processes. Other Up to 10% yearly travel is required (International, Domestic). We will ensure that individuals with disabilities are provided reasonable accommodation to participate in the job application or interview process, to perform essential job functions, and to receive other benefits and privileges of employment. Please contact us to request accommodation. Johnson & Johnson is an Affirmative Action and Equal Opportunity Employer. All qualified applicants will receive consideration for employment without regard to race, color, religion, sex, sexual orientation, gender identity, age, national origin, or protected veteran status and will not be discriminated against on the basis of disability. Primary Location Unit ...
# |Are you looking for new challenges or to make a career move to build on your software engineering skills? Do you have the technical chops to dig in deep into technical platform, and integration technologies? Do you want to have deep engagement with enterprise customers and directly observe the impact of your work? Are you jazzed by the idea of integrating multiple MS technologies into highly strategic customer focused scenarios? Are you interested in using your design, coding, troubleshooting skills to have an impact on design, best practices? If you answered “Yes” to these questions, the WWL Engineering team is for you and we would love to have join us! What we do - Within Worldwide Learning, we seek to empower learners around the world to acquire the skills enabling them to get a job, advance in their career and achieve more. Here is an opportunity for you to influence our learning programs and experiences designed to build world class capability for customers, partners, employees, and future generations. We reach millions of learners where they are, anytime, anywhere, and deliver experiences that support exploring, learning, practicing, and proving their skills. We use Microsoft Business Applications (Dynamics 365, Power platform) and Microsoft’s technical stack to augment and enhance our ability to support learners throughout their learning journey across the diversity of our program offerings. We are looking for a Senior Software Engineer to help design, develop and deliver reusable enterprise scenarios leveraging Business Applications & Power Platform which comprises of Dynamics 365, LogicApps, PowerApps, Flow, CDS, Power Automate and xRM. We are looking for a person who combines passion for customer, technical aptitude, is a team player. As a Senior Software Engineer, you will be responsible for designing, configuring, implementing the business requirements and features leveraging Dynamics 365 products that enable our mission critical business partners. This is a data-driven and fast paced environment - where Engineers are empowered to innovate and take ideas from conception to scale. It is a great opportunity to work on something highly strategic to Microsoft, especially since Business Applications is Microsoft's next billion-dollar business and we at WWL Engineering work closely with R&D team to drive feedback into the product through internal implementations, solving complex business problems. Responsibilities In this role, you’ll collaborate with cross-discipline teams to solve complex business challenges using the Dynamics 365 and Power Platform to enable successful delivery of our skilling programs and initiatives. You will also be expected to demonstrate ability to learn and adopt relevant new technologies, tools, methods and processes from Microsoft and industry. You will use every opportunity to build features to be reusable across multiple solutions, as well as leverage features from others in your solutions. More Specifically, You Will Build front-end web solutions on top of Dynamics 365 and the Power Platform (PowerApps, PowerBI, Flow) Architect platform capabilities keeping reusability, scalability and adoption in mind Drive design, requirements engineering, scrum execution, and technical discussions Detail design of the E2E solution -Utilize reference architecture in project design work Demonstrate engineering excellence through commitment to quality execution, continued improvement, and customer empathy. Mentor and act as a role model for junior developers Contribute to a team culture that embraces diversity and inclusion. To be successful in this role, you must have strong verbal and written communication skills, a positive attitude, and the creativity to tackle hard, ambiguous problems in innovate ways. You also thrive in a team environment that values cross-team collaboration and building on the success of others. Qualifications BS degree in Computer Science or equivalent experience/education 7+ years ...
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...

# %%
tokenizer = Tokenizer(inputCol="description", outputCol="words")
# Convert words to numerical vectors using TF-IDF
hashingTF = HashingTF(inputCol=tokenizer.getOutputCol(), outputCol="rawFeatures")
idf = IDF(inputCol=hashingTF.getOutputCol(), outputCol="features")
# Define the regression model
rf = RandomForestRegressor(featuresCol="features", labelCol="salary")
# Define the pipeline
pipeline = Pipeline(stages=[tokenizer, hashingTF, idf, rf])
# Split the data into training and testing sets
train_data, test_data = df.randomSplit([0.8, 0.2], seed=123)
# Train the model
model = pipeline.fit(train_data)

model.save("./")
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 tokenizer = Tokenizer(inputCol="description", outputCol="words")
#       2 # Convert words to numerical vectors using TF-IDF
#       3 hashingTF = HashingTF(inputCol=tokenizer.getOutputCol(), outputCol="rawFeatures")
#
# File ~/IdeaProjects/DataBasesAndBigDataProject/venv/lib/python3.12/site-packages/pyspark/__init__.py:139, in keyword_only.<locals>.wrapper(self, *args, **kwargs)
#     137     raise TypeError("Method %s forces keyword arguments." % func.__name__)
#     138 self._input_kwargs = kwargs
# --> 139 return func(self, **kwargs)
#
# File ~/IdeaProjects/DataBasesAndBigDataProject/venv/lib/python3.12/site-packages/pyspark/ml/feature.py:5247, in Tokenizer.__init__(self, inputCol, outputCol)
#    5243 """
#    5244 __init__(self, \\*, inputCol=None, outputCol=None)
#    5245 """
#    5246 super(Tokenizer, self).__init__()
# -> 5247 self._java_obj = self._new_java_obj("org.apache.spark.ml.feature.Tokenizer", self.uid)
#    5248 kwargs = self._input_kwargs
#    5249 self.setParams(**kwargs)
#
# File ~/IdeaProjects/DataBasesAndBigDataProject/venv/lib/python3.12/site-packages/pyspark/ml/wrapper.py:84, in JavaWrapper._new_java_obj(java_class, *args)
#      82 java_obj = _jvm()
#      83 for name in java_class.split("."):
# ---> 84     java_obj = getattr(java_obj, name)
#      85 java_args = [_py2java(sc, arg) for arg in args]
#      86 return java_obj(*java_args)
#
# File ~/IdeaProjects/DataBasesAndBigDataProject/venv/lib/python3.12/site-packages/py4j/java_gateway.py:1712, in JVMView.__getattr__(self, name)
#    1709 if name == UserHelpAutoCompletion.KEY:
#    1710     return UserHelpAutoCompletion()
# -> 1712 answer = self._gateway_client.send_command(
#    1713     proto.REFLECTION_COMMAND_NAME +
#    1714     proto.REFL_GET_UNKNOWN_SUB_COMMAND_NAME + name + "\n" + self._id +
#    1715     "\n" + proto.END_COMMAND_PART)
#    1716 if answer == proto.SUCCESS_PACKAGE:
#    1717     return JavaPackage(name, self._gateway_client, jvm_id=self._id)
#
# File ~/IdeaProjects/DataBasesAndBigDataProject/venv/lib/python3.12/site-packages/py4j/java_gateway.py:1036, in GatewayClient.send_command(self, command, retry, binary)
#    1015 def send_command(self, command, retry=True, binary=False):
#    1016     """Sends a command to the JVM. This method is not intended to be
#    1017        called directly by Py4J users. It is usually called by
#    1018        :class:`JavaMember` instances.
#    (...)
#    1034      if `binary` is `True`.
#    1035     """
# -> 1036     connection = self._get_connection()
#    1037     try:
#    1038         response = connection.send_command(command)
#
# File ~/IdeaProjects/DataBasesAndBigDataProject/venv/lib/python3.12/site-packages/py4j/clientserver.py:284, in JavaClient._get_connection(self)
#     281     pass
#     283 if connection is None or connection.socket is None:
# --> 284     connection = self._create_new_connection()
#     285 return connection
#
# File ~/IdeaProjects/DataBasesAndBigDataProject/venv/lib/python3.12/site-packages/py4j/clientserver.py:291, in JavaClient._create_new_connection(self)
#     287 def _create_new_connection(self):
#     288     connection = ClientServerConnection(
#     289         self.java_parameters, self.python_parameters,
#     290         self.gateway_property, self)
# --> 291     connection.connect_to_java_server()
#     292     self.set_thread_connection(connection)
#     293     return connection
#
# File ~/IdeaProjects/DataBasesAndBigDataProject/venv/lib/python3.12/site-packages/py4j/clientserver.py:438, in ClientServerConnection.connect_to_java_server(self)
#     435 if self.ssl_context:
#     436     self.socket = self.ssl_context.wrap_socket(
#     437         self.socket, server_hostname=self.java_address)
# --> 438 self.socket.connect((self.java_address, self.java_port))
#     439 self.stream = self.socket.makefile("rb")
#     440 self.is_connected = True
#
# ConnectionRefusedError: [Errno 61] Connection refused
